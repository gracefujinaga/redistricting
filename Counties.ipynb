# %% [markdown]
# # Imports

# %%
from pulp import *
import pandas as pd

import pulp

# %% [markdown]
# # References
#
# https://www2.census.gov/geo/docs/reference/county_adjacency.txt
#
# https://worldpopulationreview.com/us-counties
#
# https://www.elections.il.gov/electionoperations/votetotalsearch.aspx
#
# https://coin-or.github.io/pulp/CaseStudies/a_set_partitioning_problem.html

# %% [markdown]
# # Set Up

# %%
# population data

pop_data = pd.read_csv('/Users/gracefujinaga/Documents/Northwestern/MSDS_460/redistricting/pop_data.csv')
county_population = pop_data.set_index('county')['pop2024'].to_dict()
county_population

total_pop = pop_data['pop2024'].sum()

# %%
total_pop
# Out:
# 12516863

# %%
# adjacency list

def parse_illinois_counties_to_adjacency_list(file_path):
    adjacency_list = {}
    current_county = None
    
    with open(file_path, 'r') as file:
        for line in file:
            # Check if it's a main county line (no leading whitespace) and contains "IL"
            if line.startswith('"') and "IL" in line:
                # Extract the main county name
                county_name = line.split("\t")[0].strip('"')
                # Initialize an empty list of neighbors for the current county
                adjacency_list[county_name] = []
                current_county = county_name
            elif current_county and "IL" in line:
                # Only add neighboring counties in Illinois
                neighbor_county = line.strip().split("\t")[0].strip('"')
                adjacency_list[current_county].append(neighbor_county)
            
    cleaned_adjacency_list = {
        county.replace(", IL", ""): [neighbor.replace(", IL", "") for neighbor in neighbors]
        for county, neighbors in adjacency_list.items()
    }

    
    return cleaned_adjacency_list


# Example usage

adj_list = parse_illinois_counties_to_adjacency_list('/Users/gracefujinaga/Documents/Northwestern/MSDS_460/redistricting/Data/adjacency_data.txt')

# %%
# define counties
counties = list(pop_data.county)

# define districts
districts = [str(i) for i in range(1,18)]

# %%
counties
# Out:
# ['Adams County',
#  'Alexander County',
#  'Bond County',
#  'Boone County',
#  'Brown County',
#  'Bureau County',
#  'Calhoun County',
#  'Carroll County',
#  'Cass County',
#  'Champaign County',
#  'Christian County',
#  'Clark County',
#  'Clay County',
#  'Clinton County',
#  'Coles County',
#  'Cook County',
#  'Crawford County',
#  'Cumberland County',
#  'De Witt County',
#  'DeKalb County',
#  'Douglas County',
#  'DuPage County',
#  'Edgar County',
#  'Edwards County',
#  'Effingham County',
#  'Fayette County',
#  'Ford County',
#  'Franklin County',
#  'Fulton County',
#  'Gallatin County',
#  'Greene County',
#  'Grundy County',
#  'Hamilton County',
#  'Hancock County',
#  'Hardin County',
#  'Henderson County',
#  'Henry County',
#  'Iroquois County',
#  'Jackson County',
#  'Jasper County',
#  'Jefferson County',
#  'Jersey County',
#  'Jo Daviess County',
#  'Johnson County',
#  'Kane County',
#  'Kankakee County',
#  'Kendall County',
#  'Knox County',
#  'Lake County',
#  'LaSalle County',
#  'Lawrence County',
#  'Lee County',
#  'Livingston County',
#  'Logan County',
#  'Macon County',
#  'Macoupin County',
#  'Madison County',
#  'Marion County',
#  'Marshall County',
#  'Mason County',
#  'Massac County',
#  'McDonough County',
#  'McHenry County',
#  'McLean County',
#  'Menard County',
#  'Mercer County',
#  'Monroe County',
#  'Montgomery County',
#  'Morgan County',
#  'Moultrie County',
#  'Ogle County',
#  'Peoria County',
#  'Perry County',
#  'Piatt County',
#  'Pike County',
#  'Pope County',
#  'Pulaski County',
#  'Putnam County',
#  'Randolph County',
#  'Richland County',
#  'Rock Island County',
#  'Saline County',
#  'Sangamon County',
#  'Schuyler County',
#  'Scott County',
#  'Shelby County',
#  'St. Clair County',
#  'Stark County',
#  'Stephenson County',
#  'Tazewell County',
#  'Union County',
#  'Vermilion County',
#  'Wabash County',
#  'Warren County',
#  'Washington County',
#  'Wayne County',
#  'White County',
#  'Whiteside County',
#  'Will County',
#  'Williamson County',
#  'Winnebago County',
#  'Woodford County']

# %%
adj_list
# Out:
# {'Adams County': ['Brown County',
#   'Hancock County',
#   'Pike County',
#   'Schuyler County'],
#  'Alexander County': ['Pulaski County', 'Union County'],
#  'Bond County': ['Clinton County',
#   'Fayette County',
#   'Madison County',
#   'Montgomery County'],
#  'Boone County': ['DeKalb County',
#   'McHenry County',
#   'Ogle County',
#   'Winnebago County'],
#  'Brown County': ['Brown County',
#   'Cass County',
#   'Morgan County',
#   'Pike County',
#   'Schuyler County'],
#  'Bureau County': ['Henry County',
#   'LaSalle County',
#   'Lee County',
#   'Marshall County',
#   'Putnam County',
#   'Stark County',
#   'Whiteside County'],
#  'Calhoun County': ['Greene County', 'Jersey County', 'Pike County'],
#  'Carroll County': ['Jo Daviess County',
#   'Ogle County',
#   'Stephenson County',
#   'Whiteside County'],
#  'Cass County': ['Cass County',
#   'Mason County',
#   'Menard County',
#   'Morgan County',
#   'Sangamon County',
#   'Schuyler County'],
#  'Champaign County': ['Douglas County',
#   'Edgar County',
#   'Ford County',
#   'McLean County',
#   'Piatt County',
#   'Vermilion County'],
#  'Christian County': ['Macon County',
#   'Montgomery County',
#   'Sangamon County',
#   'Shelby County'],
#  'Clark County': ['Coles County',
#   'Crawford County',
#   'Cumberland County',
#   'Edgar County',
#   'Jasper County'],
#  'Clay County': ['Effingham County',
#   'Fayette County',
#   'Jasper County',
#   'Marion County',
#   'Richland County',
#   'Wayne County'],
#  'Clinton County': ['Clinton County',
#   'Fayette County',
#   'Madison County',
#   'Marion County',
#   'St. Clair County',
#   'Washington County'],
#  'Coles County': ['Coles County',
#   'Cumberland County',
#   'Douglas County',
#   'Edgar County',
#   'Moultrie County',
#   'Shelby County'],
#  'Cook County': ['DuPage County',
#   'Kane County',
#   'Lake County',
#   'McHenry County',
#   'Will County'],
#  'Crawford County': ['Crawford County',
#   'Jasper County',
#   'Lawrence County',
#   'Richland County'],
#  'Cumberland County': ['Coles County',
#   'Cumberland County',
#   'Effingham County',
#   'Jasper County',
#   'Shelby County'],
#  'DeKalb County': ['DeKalb County',
#   'Kane County',
#   'Kendall County',
#   'LaSalle County',
#   'Lee County',
#   'McHenry County',
#   'Ogle County',
#   'Winnebago County'],
#  'De Witt County': ['Logan County',
#   'McLean County',
#   'Macon County',
#   'Piatt County'],
#  'Douglas County': ['Coles County',
#   'Douglas County',
#   'Edgar County',
#   'Moultrie County',
#   'Piatt County',
#   'Vermilion County'],
#  'DuPage County': ['DuPage County',
#   'Kane County',
#   'Kendall County',
#   'Will County'],
#  'Edgar County': ['Clark County',
#   'Coles County',
#   'Douglas County',
#   'Edgar County',
#   'Vermilion County'],
#  'Edwards County': ['Richland County',
#   'Wabash County',
#   'Wayne County',
#   'White County'],
#  'Effingham County': ['Cumberland County',
#   'Effingham County',
#   'Fayette County',
#   'Jasper County',
#   'Shelby County'],
#  'Fayette County': ['Clay County',
#   'Clinton County',
#   'Effingham County',
#   'Fayette County',
#   'Marion County',
#   'Montgomery County',
#   'Shelby County'],
#  'Ford County': ['Ford County',
#   'Iroquois County',
#   'Kankakee County',
#   'Livingston County',
#   'McLean County',
#   'Vermilion County'],
#  'Franklin County': ['Hamilton County',
#   'Jackson County',
#   'Jefferson County',
#   'Perry County',
#   'Saline County',
#   'Williamson County'],
#  'Fulton County': ['Knox County',
#   'McDonough County',
#   'Mason County',
#   'Peoria County',
#   'Schuyler County',
#   'Tazewell County',
#   'Warren County'],
#  'Gallatin County': ['Hamilton County',
#   'Hardin County',
#   'Saline County',
#   'White County'],
#  'Greene County': ['Greene County',
#   'Jersey County',
#   'Macoupin County',
#   'Morgan County',
#   'Pike County',
#   'Scott County'],
#  'Grundy County': ['Kankakee County',
#   'Kendall County',
#   'LaSalle County',
#   'Livingston County',
#   'Will County'],
#  'Hamilton County': ['Gallatin County',
#   'Hamilton County',
#   'Jefferson County',
#   'Saline County',
#   'Wayne County',
#   'White County'],
#  'Hancock County': ['Hancock County',
#   'Henderson County',
#   'McDonough County',
#   'Schuyler County'],
#  'Hardin County': ['Hardin County', 'Pope County', 'Saline County'],
#  'Henderson County': ['Henderson County',
#   'McDonough County',
#   'Mercer County',
#   'Warren County'],
#  'Henry County': ['Henry County',
#   'Knox County',
#   'Mercer County',
#   'Rock Island County',
#   'Stark County',
#   'Whiteside County'],
#  'Iroquois County': ['Iroquois County', 'Kankakee County', 'Vermilion County'],
#  'Jackson County': ['Jackson County',
#   'Perry County',
#   'Randolph County',
#   'Union County',
#   'Williamson County'],
#  'Jasper County': ['Clay County',
#   'Crawford County',
#   'Cumberland County',
#   'Effingham County',
#   'Jasper County',
#   'Richland County'],
#  'Jefferson County': ['Hamilton County',
#   'Jefferson County',
#   'Marion County',
#   'Perry County',
#   'Washington County',
#   'Wayne County'],
#  'Jersey County': ['Greene County',
#   'Jersey County',
#   'Macoupin County',
#   'Madison County'],
#  'Jo Daviess County': ['Jo Daviess County', 'Stephenson County'],
#  'Johnson County': ['Massac County',
#   'Pope County',
#   'Pulaski County',
#   'Saline County',
#   'Union County',
#   'Williamson County'],
#  'Kane County': ['DeKalb County',
#   'DuPage County',
#   'Kane County',
#   'Kendall County',
#   'McHenry County'],
#  'Kankakee County': ['Grundy County',
#   'Iroquois County',
#   'Kankakee County',
#   'Livingston County',
#   'Will County'],
#  'Kendall County': ['DuPage County',
#   'Grundy County',
#   'Kane County',
#   'Kendall County',
#   'LaSalle County',
#   'Will County'],
#  'Knox County': ['Henry County',
#   'Knox County',
#   'Mercer County',
#   'Peoria County',
#   'Stark County',
#   'Warren County'],
#  'Lake County': ['Lake County', 'McHenry County'],
#  'LaSalle County': ['DeKalb County',
#   'Grundy County',
#   'Kendall County',
#   'LaSalle County',
#   'Lee County',
#   'Livingston County',
#   'Marshall County',
#   'Putnam County',
#   'Woodford County'],
#  'Lawrence County': ['Lawrence County', 'Richland County', 'Wabash County'],
#  'Lee County': ['DeKalb County',
#   'LaSalle County',
#   'Lee County',
#   'Ogle County',
#   'Whiteside County'],
#  'Livingston County': ['Grundy County',
#   'Kankakee County',
#   'LaSalle County',
#   'Livingston County',
#   'McLean County',
#   'Woodford County'],
#  'Logan County': ['Logan County',
#   'McLean County',
#   'Macon County',
#   'Mason County',
#   'Menard County',
#   'Sangamon County',
#   'Tazewell County'],
#  'McDonough County': ['Hancock County',
#   'Henderson County',
#   'McDonough County',
#   'Schuyler County',
#   'Warren County'],
#  'McHenry County': ['Cook County',
#   'DeKalb County',
#   'Kane County',
#   'Lake County',
#   'McHenry County'],
#  'McLean County': ['De Witt County',
#   'Ford County',
#   'Livingston County',
#   'Logan County',
#   'McLean County',
#   'Piatt County',
#   'Tazewell County',
#   'Woodford County'],
#  'Macon County': ['De Witt County',
#   'Logan County',
#   'Macon County',
#   'Moultrie County',
#   'Piatt County',
#   'Sangamon County',
#   'Shelby County'],
#  'Macoupin County': ['Jersey County',
#   'Macoupin County',
#   'Madison County',
#   'Montgomery County',
#   'Morgan County',
#   'Sangamon County'],
#  'Madison County': ['Clinton County',
#   'Jersey County',
#   'Macoupin County',
#   'Madison County',
#   'Montgomery County',
#   'St. Clair County'],
#  'Marion County': ['Clinton County',
#   'Fayette County',
#   'Jefferson County',
#   'Marion County',
#   'Washington County',
#   'Wayne County'],
#  'Marshall County': ['LaSalle County',
#   'Marshall County',
#   'Peoria County',
#   'Putnam County',
#   'Stark County',
#   'Woodford County'],
#  'Mason County': ['Fulton County',
#   'Logan County',
#   'Mason County',
#   'Menard County',
#   'Schuyler County',
#   'Tazewell County'],
#  'Massac County': ['Massac County', 'Pope County', 'Pulaski County'],
#  'Menard County': ['Logan County',
#   'Mason County',
#   'Menard County',
#   'Sangamon County'],
#  'Mercer County': ['Henry County',
#   'Knox County',
#   'Mercer County',
#   'Rock Island County',
#   'Warren County'],
#  'Monroe County': ['Randolph County', 'St. Clair County'],
#  'Montgomery County': ['Christian County',
#   'Fayette County',
#   'Macoupin County',
#   'Madison County',
#   'Montgomery County',
#   'Sangamon County',
#   'Shelby County'],
#  'Morgan County': ['Cass County',
#   'Greene County',
#   'Macoupin County',
#   'Morgan County',
#   'Pike County',
#   'Sangamon County',
#   'Scott County'],
#  'Moultrie County': ['Douglas County',
#   'Macon County',
#   'Moultrie County',
#   'Piatt County',
#   'Shelby County'],
#  'Ogle County': ['Carroll County',
#   'DeKalb County',
#   'Lee County',
#   'Ogle County',
#   'Stephenson County',
#   'Whiteside County',
#   'Winnebago County'],
#  'Peoria County': ['Knox County',
#   'Marshall County',
#   'Peoria County',
#   'Stark County',
#   'Tazewell County',
#   'Woodford County'],
#  'Perry County': ['Jackson County',
#   'Jefferson County',
#   'Perry County',
#   'Randolph County',
#   'Washington County'],
#  'Piatt County': ['De Witt County',
#   'Douglas County',
#   'McLean County',
#   'Macon County',
#   'Moultrie County',
#   'Piatt County'],
#  'Pike County': ['Brown County',
#   'Calhoun County',
#   'Greene County',
#   'Morgan County',
#   'Pike County',
#   'Scott County'],
#  'Pope County': ['Johnson County',
#   'Massac County',
#   'Pope County',
#   'Saline County',
#   'Williamson County'],
#  'Pulaski County': ['Johnson County',
#   'Massac County',
#   'Pulaski County',
#   'Union County'],
#  'Putnam County': ['LaSalle County', 'Marshall County', 'Putnam County'],
#  'Randolph County': ['Monroe County',
#   'Perry County',
#   'Randolph County',
#   'St. Clair County',
#   'Washington County'],
#  'Richland County': ['Crawford County',
#   'Edwards County',
#   'Jasper County',
#   'Lawrence County',
#   'Richland County',
#   'Wabash County',
#   'Wayne County'],
#  'Rock Island County': ['Mercer County',
#   'Rock Island County',
#   'Whiteside County'],
#  'St. Clair County': ['Madison County',
#   'Monroe County',
#   'Randolph County',
#   'St. Clair County',
#   'Washington County'],
#  'Saline County': ['Gallatin County',
#   'Hamilton County',
#   'Hardin County',
#   'Johnson County',
#   'Pope County',
#   'Saline County',
#   'Williamson County'],
#  'Sangamon County': ['Christian County',
#   'Logan County',
#   'Macon County',
#   'Macoupin County',
#   'Menard County',
#   'Montgomery County',
#   'Morgan County',
#   'Sangamon County'],
#  'Schuyler County': ['Brown County',
#   'Cass County',
#   'Fulton County',
#   'Hancock County',
#   'McDonough County',
#   'Mason County',
#   'Schuyler County'],
#  'Scott County': ['Morgan County', 'Pike County', 'Scott County'],
#  'Shelby County': ['Coles County',
#   'Cumberland County',
#   'Effingham County',
#   'Fayette County',
#   'Macon County',
#   'Montgomery County',
#   'Moultrie County',
#   'Shelby County'],
#  'Stark County': ['Henry County',
#   'Knox County',
#   'Marshall County',
#   'Peoria County',
#   'Stark County'],
#  'Stephenson County': ['Jo Daviess County',
#   'Ogle County',
#   'Stephenson County',
#   'Winnebago County'],
#  'Tazewell County': ['Logan County',
#   'McLean County',
#   'Mason County',
#   'Peoria County',
#   'Tazewell County',
#   'Woodford County'],
#  'Union County': ['Jackson County',
#   'Johnson County',
#   'Pulaski County',
#   'Union County',
#   'Williamson County'],
#  'Vermilion County': ['Douglas County',
#   'Edgar County',
#   'Ford County',
#   'Iroquois County',
#   'Vermilion County'],
#  'Wabash County': ['Lawrence County',
#   'Richland County',
#   'Wabash County',
#   'White County'],
#  'Warren County': ['Henderson County',
#   'Knox County',
#   'McDonough County',
#   'Mercer County',
#   'Warren County'],
#  'Washington County': ['Jefferson County',
#   'Marion County',
#   'Perry County',
#   'Randolph County',
#   'St. Clair County',
#   'Washington County'],
#  'Wayne County': ['Edwards County',
#   'Hamilton County',
#   'Jefferson County',
#   'Marion County',
#   'Richland County',
#   'Wayne County',
#   'White County'],
#  'White County': ['Gallatin County',
#   'Hamilton County',
#   'Wabash County',
#   'Wayne County',
#   'White County'],
#  'Whiteside County': ['Carroll County',
#   'Henry County',
#   'Lee County',
#   'Ogle County',
#   'Rock Island County',
#   'Whiteside County'],
#  'Will County': ['DuPage County',
#   'Grundy County',
#   'Kankakee County',
#   'Kendall County',
#   'Will County'],
#  'Williamson County': ['Jackson County',
#   'Johnson County',
#   'Pope County',
#   'Saline County',
#   'Union County',
#   'Williamson County'],
#  'Winnebago County': ['DeKalb County',
#   'Ogle County',
#   'Stephenson County',
#   'Winnebago County'],
#  'Woodford County': ['Livingston County',
#   'McLean County',
#   'Marshall County',
#   'Peoria County',
#   'Tazewell County',
#   'Woodford County']}

# %% [markdown]
# # LP Problem

# %%
#create dictionary for county names with their population sizes, adjacency, latitude, longitude, etc
county_dict = {
    row['name']: {
        "pop2024": row['pop2024'],
        "pop2020": row['pop2020'],
        "adjacentcodes": row['AdjacentCodes']
    }
    for _, row in county_data_df.iterrows()
}

#max_districts
max_districts = 17
#max_districts size? (max counties in district)

#list of all possible districts
possible_districts = [tuple(c) for c in pulp.allcombinations(counties, max_population_size)]
#would be better to use max/min population sizes?

#create binary variable to state county is in a district
x = pulp.LpVariable.dicts(
    "table", possible_districts, lowBound=0, upBound=1, cat=pulp.LpInteger
)
redistprob = pulp.LpProblem("Redistrict_probModel", pulp.LpMinimize)

#distance function (used in obj function)
#GIS distance calculations code from the assignment page
#requires latitude and longitude

#obj function, Sum of population per district is as close to equal as possible


#obj function, least distance between the furthest counties?
redistprob += pulp.lpSum([distance(district) * x[district] for district in possible_districts])

# specify the maximum number of districts
redistprob += (
    pulp.lpSum([x[district] for district in possible_districts]) <= max_districts,
    "Maximum_number_of_districts",
)


#Counties in the same congressional district must be adjacent
#List of counties in district, check adjacent counties column

#Sum of population per district is within average +/- 5% range
#2 constraints, x< pop average+5%, x> pop average 05%

#At least one county per district
# A guest must seated at one and only one table
#guest are counties
#tables are districts
for county in counties:
    redistprob += (
        pulp.lpSum([x[district] for district in possible_districts if county in district]) >= 1,
        f"Must_seat_{county}",
    )
    
#Every county must be in exactly one district


#Maximum number of counties per district (potentially)
#Maximum distance between furthest counties in a district (potentially)
#Proportional number of majority Democrat/Republican districts to popular split of Democratic and Republican votes from 2020/2022

# %%
#####
import pulp

max_tables = 5
max_table_size = 4
guests = "A B C D E F G I J K L M N O P Q R".split()


def happiness(table):
    """
    Find the happiness of the table
    - by calculating the maximum distance between the letters
    """
    return abs(ord(table[0]) - ord(table[-1]))


# create list of all possible tables
possible_tables = [tuple(c) for c in pulp.allcombinations(guests, max_table_size)]

# create a binary variable to state that a table setting is used
x = pulp.LpVariable.dicts(
    "table", possible_tables, lowBound=0, upBound=1, cat=pulp.LpInteger
)

seating_model = pulp.LpProblem("Wedding Seating Model", pulp.LpMinimize)

seating_model += pulp.lpSum([happiness(table) * x[table] for table in possible_tables])

# specify the maximum number of tables
seating_model += (
    pulp.lpSum([x[table] for table in possible_tables]) <= max_tables,
    "Maximum_number_of_tables",
)

# A guest must seated at one and only one table
for guest in guests:
    seating_model += (
        pulp.lpSum([x[table] for table in possible_tables if guest in table]) == 1,
        f"Must_seat_{guest}",
    )

seating_model.solve()

print(f"The chosen tables are out of a total of {len(possible_tables)}:")
for table in possible_tables:
    if x[table].value() == 1.0:
        print(table)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pulp/pulp.py:1298: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/p4/prvgygc14vd8rmhsv2qx4rxc0000gn/T/2fa5c27e52354c9cb29a396b81a52e9c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/p4/prvgygc14vd8rmhsv2qx4rxc0000gn/T/2fa5c27e52354c9cb29a396b81a52e9c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 23 COLUMNS
# At line 24708 RHS
# At line 24727 BOUNDS
# At line 27941 ENDATA
# Problem MODEL has 18 rows, 3213 columns and 15062 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12 - 0.01 seconds
# Cgl0004I processed model has 18 rows, 3213 columns (3213 integer (3213 of which binary)) and 15062 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 12
# Cbc0038I Before mini branch and bound, 3213 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 12 - took 0.01 seconds
# Cbc0012I Integer solution of 12 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0001I Search completed - best objective 12, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 12 to 12
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.05
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.12
#
# The chosen tables are out of a total of 3213:
# ('M', 'N')
# ('E', 'F', 'G')
# ('A', 'B', 'C', 'D')
# ('I', 'J', 'K', 'L')
# ('O', 'P', 'Q', 'R')

# %% [markdown]
# ## Grace's Attempt

# %%
## attempt 3

#num_districts
districts = 17

# max number of counties per district - probably should be increased but its really heavy to run
max_district_size = 5

# objective function?
def happiness(table):
    """
    Find the happiness of the table
    - by calculating the maximum distance between the letters
    """
    return abs(ord(table[0]) - ord(table[-1]))


# create list of all possible districts
possible_districts = [tuple(c) for c in pulp.allcombinations(counties, max_district_size)]

# create a binary variable to state whether or not that district is being used
x = pulp.LpVariable.dicts(
    "district", possible_districts, lowBound=0, upBound=1, cat=pulp.LpInteger
)

redistricting_model = pulp.LpProblem("Wedding Seating Model", pulp.LpMinimize)

# objective function
redistricting_model += pulp.lpSum([happiness(county) * x[county] for county in possible_districts])

# -------------------------------- CONSTRAINTS ---------------------------

# specify the number of districts
redistricting_model += (
    pulp.lpSum([x[county] for county in possible_districts]) == 17,
    "17 districts",
)

# A county must be in exactly one district
for county in counties:
    redistricting_model += (
        pulp.lpSum([x[district] for district in possible_districts if county in district]) == 1,
        f"Must_allocate_{county}",
    )

# TODO: Counties must be adjacent to one another

# TODO: Some type of maximum distance?

redistricting_model.solve()

print(f"The chosen districts are out of a total of {len(possible_districts)}:")
for district in possible_districts:
    if x[county].value() == 1.0:
        print(county)
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10680e940>>
# Traceback (most recent call last):
#   File "/Users/gracefujinaga/Library/Python/3.9/lib/python/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:

# %% [markdown]
# The above code took 27+ minutes to run just through adding the objective function with very minimal constraints, we might need to pair it down to fewer options and run the code multiple times or use GPU. Just things to note. The code below adds more constraints

# %%
county_population
# Out:
# {'Adams County': 64326,
#  'Alexander County': 4549,
#  'Bond County': 16364,
#  'Boone County': 53336,
#  'Brown County': 6272,
#  'Bureau County': 32631,
#  'Calhoun County': 4281,
#  'Carroll County': 15473,
#  'Cass County': 12554,
#  'Champaign County': 205119,
#  'Christian County': 33066,
#  'Clark County': 15016,
#  'Clay County': 12921,
#  'Clinton County': 36633,
#  'Coles County': 45774,
#  'Cook County': 5062578,
#  'Crawford County': 18105,
#  'Cumberland County': 10214,
#  'De Witt County': 15365,
#  'DeKalb County': 100353,
#  'Douglas County': 19591,
#  'DuPage County': 920762,
#  'Edgar County': 16283,
#  'Edwards County': 5878,
#  'Effingham County': 34362,
#  'Fayette County': 21058,
#  'Ford County': 13244,
#  'Franklin County': 37061,
#  'Fulton County': 32147,
#  'Gallatin County': 4517,
#  'Greene County': 11446,
#  'Grundy County': 54007,
#  'Hamilton County': 7841,
#  'Hancock County': 17118,
#  'Hardin County': 3566,
#  'Henderson County': 6008,
#  'Henry County': 48300,
#  'Iroquois County': 25779,
#  'Jackson County': 51805,
#  'Jasper County': 9116,
#  'Jefferson County': 36221,
#  'Jersey County': 20991,
#  'Jo Daviess County': 21667,
#  'Johnson County': 13261,
#  'Kane County': 515825,
#  'Kankakee County': 105882,
#  'Kendall County': 142458,
#  'Knox County': 48202,
#  'Lake County': 707621,
#  'LaSalle County': 108437,
#  'Lawrence County': 14735,
#  'Lee County': 33370,
#  'Livingston County': 35123,
#  'Logan County': 27514,
#  'Macon County': 99849,
#  'Macoupin County': 43913,
#  'Madison County': 261932,
#  'Marion County': 36441,
#  'Marshall County': 11695,
#  'Mason County': 12347,
#  'Massac County': 13495,
#  'McDonough County': 26764,
#  'McHenry County': 314042,
#  'McLean County': 169964,
#  'Menard County': 11836,
#  'Mercer County': 15441,
#  'Monroe County': 34913,
#  'Montgomery County': 27425,
#  'Morgan County': 31982,
#  'Moultrie County': 14309,
#  'Ogle County': 51185,
#  'Peoria County': 177026,
#  'Perry County': 20494,
#  'Piatt County': 16753,
#  'Pike County': 14185,
#  'Pope County': 3668,
#  'Pulaski County': 4872,
#  'Putnam County': 5569,
#  'Randolph County': 29604,
#  'Richland County': 15421,
#  'Rock Island County': 140913,
#  'Saline County': 22694,
#  'Sangamon County': 192831,
#  'Schuyler County': 6713,
#  'Scott County': 4649,
#  'Shelby County': 20426,
#  'St. Clair County': 249771,
#  'Stark County': 5123,
#  'Stephenson County': 42654,
#  'Tazewell County': 129472,
#  'Union County': 16562,
#  'Vermilion County': 71201,
#  'Wabash County': 10844,
#  'Warren County': 16010,
#  'Washington County': 13449,
#  'Wayne County': 15679,
#  'White County': 13207,
#  'Whiteside County': 54441,
#  'Will County': 703410,
#  'Williamson County': 66868,
#  'Winnebago County': 280302,
#  'Woodford County': 38393}

# %%
# Parameters
num_districts = 17
max_district_size = int(len(counties)/num_districts)

# Define possible districts
possible_districts = [tuple(c) for c in pulp.allcombinations(counties, max_district_size)]

# Define binary variables for district selection
x = pulp.LpVariable.dicts("district", possible_districts, lowBound=0, upBound=1, cat=pulp.LpInteger)

# Create auxiliary variables for the absolute deviation from target population
abs_diff = pulp.LpVariable.dicts("abs_diff", possible_districts, lowBound=0, cat=pulp.LpContinuous)

# Create the model
redistricting_model = pulp.LpProblem("Redistricting Model", pulp.LpMinimize)

# Calculate target population
target_population = total_pop / num_districts

# Objective function: minimize absolute population difference
redistricting_model += pulp.lpSum(abs_diff[district] for district in possible_districts), "Minimize_Absolute_Difference"

# CONSTRAINTS -------------------------------

# Constraint to calculate absolute deviation for each district
for district in possible_districts:
    redistricting_model += (
        pulp.lpSum(county_population.get(county, 0) for county in district) - target_population <= abs_diff[district]
    ), f"Positive_Deviation_{district}"
    redistricting_model += (
        target_population - pulp.lpSum(county_population.get(county, 0) for county in district) <= abs_diff[district]
    ), f"Negative_Deviation_{district}"

# Constraint: number of districts
redistricting_model += (
    pulp.lpSum([x[district] for district in possible_districts]) == num_districts,
    f"{num_districts} districts",
)

# Constraint: each county in exactly one district
for county in counties:
    redistricting_model += (
        pulp.lpSum([x[district] for district in possible_districts if county in district]) == 1,
        f"Must_allocate_{county}",
    )

# Constraint: counties must be adjacent to one another
for district in possible_districts:
    for county in district:
        neighbors = set(adj_list[county])
        if not any(neighbor in district for neighbor in neighbors if neighbor != county):
            redistricting_model += x[district] == 0, f"Contiguity_failed_{district}_{county}"

# Solve the model
redistricting_model.solve()

# Output the chosen districts
print(f"The chosen districts are out of a total of {len(possible_districts)}:")
for district in possible_districts:
    if x[district].value() == 1.0:
        print(district)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
